# %%
import pandas as pd
df = pd.read_csv('Credit.csv')
df
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# 5             6   80.180   8047     569      4   77         10    Male
# 6             7   20.996   3388     259      2   37         12  Female
# 7             8   71.408   7114     512      2   87          9    Male
# 8             9   15.125   3300     266      5   66         13  Female
# 9            10   71.061   6819     491      3   41         19  Female
# 10           11   63.095   8117     589      4   30         14    Male
# 11           12   15.045   1311     138      3   64         16    Male
# ...

# %%
# Plotting Income against Limit
df.plot(kind = 'scatter', x = 'Income', y = 'Limit')

# %%
# Plotting Rating against Limit
df.plot(kind = 'scatter', x = 'Rating', y = 'Limit')

# %%
# Plotting Cards against Limit
df.plot(kind = 'scatter', x = 'Cards', y = 'Limit')

# %%
# Plotting Age against Limit
df.plot(kind = 'scatter', x = 'Age', y = 'Limit')

# %%
# Plotting Education against Limit
df.plot(kind = 'scatter', x = 'Education', y = 'Limit')

# %%
ax1 = df.plot(kind='scatter', x='Income', y='Limit', color='g')    
ax2 = df.plot(kind='scatter', x='Rating', y='Limit', color='b', ax=ax1)    
ax3 = df.plot(kind='scatter', x='Cards', y='Limit', color='orange', ax=ax1)
ax4 = df.plot(kind='scatter', x='Age', y='Limit', color='red', ax=ax1)
ax5 = df.plot(kind='scatter', x='Education', y='Limit', color='purple', ax=ax1)

# %%
import seaborn as sns

res=sns.residplot('Income', 'Limit', data = df)
res.set(xlabel = 'Income', ylabel = 'Residuals')
# Out:
# [Text(0,0.5,'Residuals'), Text(0.5,0,'Income')]

# %%
import seaborn as sns

res=sns.residplot('Rating', 'Limit', data = df)
res.set(xlabel = 'Rating', ylabel = 'Residuals')
# Out:
# [Text(0,0.5,'Residuals'), Text(0.5,0,'Rating')]

# %%
import seaborn as sns

res=sns.residplot('Cards', 'Limit', data = df)
res.set(xlabel = 'Cards', ylabel = 'Residuals')
# Out:
# [Text(0,0.5,'Residuals'), Text(0.5,0,'Cards')]

# %%
import seaborn as sns

res=sns.residplot('Age', 'Limit', data = df)
res.set(xlabel = 'Age', ylabel = 'Residuals')
# Out:
# [Text(0,0.5,'Residuals'), Text(0.5,0,'Age')]

# %%
import seaborn as sns

res=sns.residplot('Education', 'Limit', data = df)
res.set(xlabel = 'Education', ylabel = 'Residuals')
# Out:
# [Text(0,0.5,'Residuals'), Text(0.5,0,'Education')]

# %%
#Income
from sklearn.linear_model import LinearRegression
linReg = LinearRegression().fit(df.filter(items=['Limit']),df.iloc[:, 1])
linReg
print(linReg.coef_)
print(linReg.intercept_)
print("Income")
# Out:
# [0.01209453]
# -12.055966478174383
# Income

# %%
#Rating
from sklearn.linear_model import LinearRegression
linReg = LinearRegression().fit(df.filter(items=['Limit']),df.iloc[:, 3])
linReg
print(linReg.coef_)
print(linReg.intercept_)
print("Rating")
# Out:
# [0.06682326]
# 38.49178870915216
# Rating

# %%
#Cards
from sklearn.linear_model import LinearRegression
linReg = LinearRegression().fit(df.filter(items=['Limit']),df.iloc[:, 4])
linReg
print(linReg.coef_)
print(linReg.intercept_)
print("Cards")
# Out:
# [6.07831934e-06]
# 2.9287155109180927
# Cards

# %%
#Age
from sklearn.linear_model import LinearRegression
linReg = LinearRegression().fit(df.filter(items=['Limit']),df.iloc[:, 5])
linReg
print(linReg.coef_)
print(linReg.intercept_)
print("Age")
# Out:
# [0.00075396]
# 52.097031537165535
# Age

# %%
#Education
from sklearn.linear_model import LinearRegression
linReg = LinearRegression().fit(df.filter(items=['Limit']),df.iloc[:, 6])
linReg
print(linReg.coef_)
print(linReg.intercept_)
print("Education")
# Out:
# [-3.18837514e-05]
# 13.600988693077541
# Education
